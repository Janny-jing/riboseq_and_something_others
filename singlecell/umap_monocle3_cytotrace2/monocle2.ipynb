# %%
import scanpy as sc

# %%
adata = sc.read_h5ad("Ximerakis.h5ad")

# %%
adata.var
# Out:
#             variable_genes
# Sox17                 True
# Mrpl15               False
# Lypla1               False
# Tcea1                False
# Rgs20                False
# ...                    ...
# mt-Cytb              False
# Vamp7                False
# AC168977.1           False
# PISD                 False
# DHRSX                False
#
# [14699 rows x 1 columns]
